# %%
#import libraries
import pandas as pd
import numpy as np
import requests
import psycopg2
import re
from bs4 import BeautifulSoup
import seaborn as sns
import matplotlib.pyplot as plt
import scipy

# %% [markdown]
# ### Function to create connection to our PostgreSQL database

# %%
# Function to create connection to our PostgreSQL database
def get_connection():
    """Function to create connection to our PostgreSQL database"""
    connection = psycopg2.connect(user = "postgres",
                                  password = 'hangnguyen',
                                  host = "127.0.0.1",
                                  port = "5432",
                                  database = "tiki")
    return connection

# %% [markdown]
# ### Create table product to hold information of all the products on tiki

# %%
def create_table_product():
    """Create table product to hold information of all the products on tiki"""
    # get connection to PostgreSQL database using get_connection() function
    conn = get_connection()
    # create cursor
    cursor = conn.cursor()
    
    # create table
    cursor.execute("""
    CREATE TABLE IF NOT EXISTS Product
    (
        id INT,
        seller_id INT,
        title VARCHAR(700),
        brand VARCHAR(700),
        price FLOAT,
        discount INT,
        rating INT,
        tikinow INT,
        subcategory VARCHAR(500),
        category VARCHAR(500),
        image VARCHAR(700)
    )
    """)
    
    # save the change 
    conn.commit()

# %% [markdown]
# ### Function to parse url to get the HTML code

# %%
#The third function parsers(url) will get the HTML code from the website, and return the parsed version of it, allowing us to pull data from it
def parseUrl(url):
    """Get a parsed version of url"""
    plain = requests.get(url).text
    
    # Parser. 
    # Hint: Use BeautifulSoup
    s = BeautifulSoup(plain,features="lxml")
    
    return s

# %% [markdown]
# ### Get the URLs of all categories on Tiki homepage

# %%
# The fourth function get_urls() will get all the categories on tiki and the urls of those categories  
def get_urls():
    """Get the URLs of all categories on Tiki homepage"""
    
    url = 'https://tiki.vn/'
    # parse url
    s = parseUrl(url)

    # create an empty list to contain the name of all the categories with the url link to a specific product's page
    categories = []
    
    #Iterator through all the a tag which contains the information of each category and their url
    for i in s.find_all("a",class_ = "MenuItem__MenuLink-tii3xq-1 efuIbv"):
        # find the category's name
        cat = i.find_all("span",class_="text")[0].string
        # find the url of that category
        url = i.get("href")
        # append 
        categories.append((cat,url))
    
    return categories

# %% [markdown]
# ### Scrape product's information on 1 page

# %%
# The final function
def scrape(cat,url):
    """Scrape product's information on 1 page"""
    # get connection to PostgreSQL database using get_connection() function
    conn = get_connection()
    # create cursor
    cursor = conn.cursor()
    
    # create a product list to hold the product's information of that page
    products = []

    # parse url using the parse function
    s = parseUrl(url)

    # find the div tag that contains information of each product on that page
    product_items = s.find_all("div",class_="product-item")

    # find the next page
    flag = 0
    urls = s.find_all("a",class_="normal")
    if len(s.find_all("span",class_="current"))!=0:
        curr = int(s.find_all("span",class_="current")[0].text)

        # Iterator through list of pages in that category
        for u in urls:
            # Check whether there is a link to the next page 
            if int(u.text) > int(curr):
                flag = 1
                next_url = "https://tiki.vn"+u.get("href")
                break

    if flag == 0:
        next_url = None
    # If that tag is empty (i.e. the page doesn't have any product), return an empty list.
    if len(product_items) == 0:
        return None

    # If that tag is not empty (i.e. the page has products),...
    else: 
        
        # Iterate through all product_items and store the product information in the 'row' list
        for i in range(len(product_items)):
        # The order of items in row is: 
        # data-id -> data-seller-product-id -> data-title -> data_brand -> data-price -> discount
        # rating -> tikinow  ->sub category -> cat (category) -> product-image
            # check whether the product is available for tikinow
            tikinow = 0
            if len(product_items[i].find_all("i",class_="icon-tikinow")) != 0:
                tikinow = 1
            
            # find the category of the product
            sub_cat = product_items[i]['data-category'].split("-")[0]
            
            # find the rating rate
            ratings = product_items[i].find_all("span",class_="rating-content")
            # If the product has rating then take only the rating percentage
            # Else asign the rating with np.nan
            if len(ratings) != 0:
                rating = int(ratings[0].span["style"].split(":")[1].split("%")[0])
            else:
                rating = None
                
            # find the rate of discount
            discount_tag_content = product_items[i].find_all("span",class_="sale-tag-square")[0].text
            if len(discount_tag_content)!=0:
                discount = int(re.findall("[0-9]+",discount_tag_content)[0])
            else:
                discount = None
                
            row_product = (product_items[i]['data-id'], 
                   product_items[i]['data-seller-product-id'], 
                   product_items[i]['data-title'],
                   product_items[i]['data-brand'],
                   product_items[i]['data-price'] if len(product_items[i]['data-price'])!=0 else None,
                   discount,
                   rating, 
                   tikinow, 
                   sub_cat,
                   cat,
                   product_items[i].a.img['src']
                          )
            cursor.execute("INSERT INTO Product VALUES(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)",row_product)
        
        conn.commit()
    conn.close()
    # Return the url of the next page
    return next_url

# %% [markdown]
# ### Scrape all product on tiki

# %%
def scrape_all():
    # create a queue that store the category's name and a link to their respective product page
    queue = [list(i) for i in get_urls()]

    while len(queue)!=0:
        # get the url link of the last item in queue
        url = queue[-1][1]
        
        # get the name of the category of the last item in the queue 
        cat = queue[-1][0]
        print('Scraping', cat)

        # pop the last item out of the queue
        queue = queue[:-1]
        
        # check whether the link exists or not
        if url != None:
            next_url = scrape(cat,url)
            # check whether the link to the next page exists or not
            if next_url:
                queue.append((cat,next_url))
                print('Add next page', next_url)

# %% [markdown]
# ### Test function scrape_all()

# %%
scrape_all()
# Out:
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=2
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=3
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=4
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=5
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=6
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=7
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=8
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=9
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=10
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=11
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=12
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=13
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=14
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=15
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=16
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=17
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=18
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=19
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=20
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=21
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=22
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=23
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=24
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=25
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=26
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=27
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=28
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=29
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=30
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=31
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=32
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=33
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=34
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=35
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=36
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=37
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=38
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=39
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=40
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=41
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=42
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=43
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=44
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=45
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=46
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=47
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=48
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=49
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=50
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=51
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=52
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=53
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=54
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=55
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=56
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=57
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=58
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=59
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=60
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=61
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=62
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=63
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=64
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=65
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=66
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=67
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=68
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=69
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=70
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=71
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=72
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=73
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=74
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=75
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=76
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=77
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=78
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=79
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=80
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=81
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=82
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=83
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=84
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=85
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=86
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=87
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=88
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=89
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=90
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=91
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=92
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=93
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=94
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=95
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=96
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=97
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Add next page https://tiki.vn/voucher-dich-vu/c11312?src=c.11312.hamburger_menu_fly_out_banner&page=98
# Scraping Voucher - Dịch Vụ - Thẻ Cào
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=2
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=3
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=4
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=5
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=6
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=7
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=8
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=9
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=10
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=11
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=12
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=13
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=14
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=15
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=16
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=17
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=18
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=19
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=20
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=21
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=22
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=23
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=24
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=25
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=26
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=27
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=28
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=29
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=30
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=31
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=32
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=33
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=34
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=35
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=36
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=37
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=38
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=39
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=40
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=41
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=42
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=43
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=44
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=45
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=46
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=47
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=48
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=49
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=50
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=51
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=52
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=53
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=54
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=55
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=56
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=57
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=58
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=59
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=60
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=61
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=62
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=63
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=64
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=65
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=66
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=67
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=68
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=69
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=70
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page=71
# Scraping Sách, VPP & Quà Tặng
# Add next page https://tiki.vn/nha-sach-tiki/c8322?src=c.8322.hamburger_menu_fly_out_banner&page
# Scraping Điện Thoại - Máy Tính Bảng
# Add next page https://tiki.vn/dien-thoai-may-tinh-bang/c1789?src=c.1789.hamburger_menu_fly_out_banner&page=20
# Scraping Điện Thoại - Máy Tính Bảng
# Add next page https://tiki.vn/dien-thoai-may-tinh-bang/c1789?src=c.1789.hamburger_menu_fly_out_banner&page=21
# Scraping Điện Thoại - Máy Tính Bảng

# %% [markdown]
# ### Select data from the product table in Postgres and put it into dataframe

# %%
def create_dataframe_products():
    """This function will select data from the product table in Postgres and put it into dataframe"""
    
    # get connection to tiki database in Postgres
    conn = get_connection()
    
    # create cursor
    cursor = conn.cursor()
    
    # select all of data in the product table
    cursor.execute("SELECT * FROM Product;")
    
    # put the result in to dataframe
    df_products = pd.DataFrame(arr, columns = ['product_id', 
                                              'seller_id', 
                                              'title',
                                              'brand',
                                              'price',
                                              'discount', 
                                              'rating',
                                              'tikinow',
                                              'subcategory',
                                              'category', 
                                              'image' ]
                              )
    
    # close the connection
    conn.close()
    
    # return dataframe
    return df_products

# %% [markdown]
# ### Test function create_dataframe_products()

# %%
products = create_dataframe_products()
products.tail()
# Out:
#         product_id  seller_id  \
# 141036     3717703    3717707
# 141037    19845668   19846490
# 141038    23228658   23228660
# 141039    23105947   23105949
# 141040    14380981   14380983
#
#                                                     title    brand  \
# 141036  Điện Thoại Di Động GSM ZONO N8110 2.4inch – Hà...     Zono
# 141037          Xiaomi Redmi 7 (2G/16G) - Hàng chính hãng   Xiaomi
# 141038  Điện Thoại Samsung Galaxy S8 (4GB / 64GB) - Bả...  Samsung
# 141039       Điện Thoại Itel Alpha Lite - Hàng Chính Hãng     Itel
# 141040  Điện Thoại Samsung Galaxy A80 (128GB/8GB) - Hà...  Samsung
#
#              price  discount  rating  tikinow  subcategory  \
# 141036    199000.0      62.0    50.0        1  Điện Thoại
# 141037   2920000.0      31.0     NaN        0
# 141038   6390000.0      12.0     NaN        0
# 141039   1050000.0      12.0     NaN        0
# 141040  14990000.0       NaN     NaN        0  Điện Thoại
#
#                           category  \
# 141036  Điện Thoại - Máy Tính Bảng
# 141037  Điện Thoại - Máy Tính Bảng
# 141038  Điện Thoại - Máy Tính Bảng
# 141039  Điện Thoại - Máy Tính Bảng
# 141040  Điện Thoại - Máy Tính Bảng
#
#                                                     image
# 141036  https://salt.tikicdn.com/cache/200x200/ts/prod...
# 141037  https://salt.tikicdn.com/cache/200x200/ts/prod...
# 141038  https://salt.tikicdn.com/cache/200x200/ts/prod...
# 141039  https://salt.tikicdn.com/cache/200x200/ts/prod...
# 141040  https://salt.tikicdn.com/cache/200x200/ts/prod...

# %% [markdown]
# <h1> Analysis

# %% [markdown]
# #### Price

# %% [markdown]
# ##### Which category has the highest mean price ?

# %%
mean_price = products.groupby("category")["price"].mean().sort_values(ascending=False)
plt.figure(figsize=(20,10))
sns.barplot(y = mean_price.index,x = mean_price.values)

# %%
categories = df["category"].unique()
categories.shape[0]
# Out:
# 16

# %%
def brand_price(df):
    mean_price = df.groupby(["brand","subcategory"])["price"].mean().sort_values(ascending=False)
    plt.figure(figsize=(20,30))
    sns.barplot(y = mean_price.index,x = mean_price.values)

# %%
dienthoai = products[products["category"]=="Điện Thoại - Máy Tính Bảng"]
brand_price(dienthoai)

# %%
def brand_discount(df):
    mean_price = df.groupby("brand")["discount"].mean().sort_values(ascending=False).head(15)
    plt.figure(figsize=(20,10))
    sns.barplot(y = mean_price.index,x = mean_price.values)

# %%
dienthoai = products[products["category"]=="Điện Thoại - Máy Tính Bảng"]
brand_discount(dienthoai)

# %%
dienthoai[["discount","price"]].corr()
# Out:
#           discount     price
# discount  1.000000 -0.203992
# price    -0.203992  1.000000
